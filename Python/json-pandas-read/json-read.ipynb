# %%
import pandas as pd
import numpy as np
import json
import gzip
import base64

# %%
my_file = '/Users/nguyenhoangphuc/Downloads/previous-similar-projects/Python/json-pandas-read/data.json'

# %%
with open(my_file, 'rb') as fd:
    gzip_fd = gzip.GzipFile(fileobj=fd)
    df = pd.read_json(gzip_fd, lines=True)
    display(df)
    
    df.to_json('/Users/nguyenhoangphuc/Downloads/converted.json')
    df.to_json('/Users/nguyenhoangphuc/Downloads/converted_wgz.json',compression='gzip')
# Out:
#             date                                               repo  \
# 0     2022-08-29  {'name': 'github.com/VibhorCodecianGupta/Argus...
# 1     2022-08-29  {'name': 'github.com/dvanderweele/lessqlite', ...
# 2     2022-08-29  {'name': 'github.com/messagebird/python-rest-a...
# 3     2022-08-29  {'name': 'github.com/lablup/sorna-agent', 'com...
# 4     2022-08-29  {'name': 'github.com/imagina/qblog', 'commit':...
# ...          ...                                                ...
# 17879 2022-08-29  {'name': 'github.com/paketo-buildpacks/native-...
# 17880 2022-08-29  {'name': 'github.com/QuorumControl/tupelo-js-s...
# 17881 2022-08-29  {'name': 'github.com/proyecto26/react-native-i...
# 17882 2022-08-29  {'name': 'github.com/ovh-ux/ovh-angular-otrs',...
# 17883 2022-08-29  {'name': 'github.com/aws-samples/eks-workshop'...
#
#                                                scorecard  \
# 0      {'version': 'v4.6.0-17-g6fc08e7', 'commit': '6...
# ...
