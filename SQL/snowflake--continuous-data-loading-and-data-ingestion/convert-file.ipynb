# %%
import pandas as pd
import numpy as np
import google_sheet as gs

# %%
df = pd.read_csv(r'/Users/nguyenhoangphuc/Downloads/2022100100_data_28_4_0.csv',delimiter="\t",on_bad_lines='skip',header=None,low_memory=False)

df
# Out:
#                                0                    1               2   \
# 0        40d7360cba7911e814bd8f5c  2022-10-01 00:08:41  73.111.194.117
# 1        64baa3daba802a123efb705c  2022-10-01 00:54:45   76.105.254.11
# 2        eac2ef18cd69636fef14e45c  2022-10-01 00:32:06  67.251.102.146
# 3        3a3690f8129c853d0fd5185c  2022-10-01 00:48:40  32.219.171.177
# 4        179d4c56902c303b0f99441c  2022-10-01 00:22:26   50.32.154.123
# ...                           ...                  ...             ...
# 1437635  E1mRUGZHYQ2MWy2URcCr1zBd  2022-10-01 00:47:24     66.75.1.114
# 1437636  FGpNEGZHKhtDA8MHSXewVyBd  2022-10-01 00:33:14   107.3.191.172
# 1437637  FGpNEGZHKhtDA8MHSXewVyBd  2022-10-01 00:39:26   107.3.191.172
# 1437638  FGpNEGZHKhtDA8MHSXewVyBd  2022-10-01 00:46:41   107.3.191.172
# 1437639  FZ78UBZHSvDMU6N-TFabWAGL  2022-10-01 00:01:21   100.15.75.156
#
#                                     3   \
# 0            en.redshirtsalwaysdie.com
# ...

# %%
df.to_csv(r'/Users/nguyenhoangphuc/Downloads/2022100100_data_28_4_0.csv.gz', sep="\t", index=False, compression='gzip',header=False)
